# %% [markdown]
# ## Exploratory analysis of IMDB dataset

# %%
# Execution time: 7.5 mins
# Nrows: ~9M
nb <- read.delim("D:/Users/arf/OneDrive/Documentos/Aulas/2021/VD/Project/Dataset/NameBasics.tsv", header=TRUE)

# %%
# Execution time: 6.5 mins
#Nrows: ~15M
ta <- read.delim("D:/Users/arf/OneDrive/Documentos/Aulas/2021/VD/Project/Dataset/TitleAkas.tsv", header=TRUE)

# %%
# Execution time: 4.5 mins
# Nrows: ~7M
tb <- read.delim("D:/Users/arf/OneDrive/Documentos/Aulas/2021/VD/Project/Dataset/TitleBasics.tsv", header=TRUE)

# %%
# Execution time: 1.5 mins
#Nrows: ~7M
tc <- read.delim("D:/Users/arf/OneDrive/Documentos/Aulas/2021/VD/Project/Dataset/TitleCrew.tsv", header=TRUE)

# %%
# Execution time: 6.5 mins
# Nrows: ~23M
tp <- read.delim("D:/Users/arf/OneDrive/Documentos/Aulas/2021/VD/Project/Dataset/TitlePrincipals.tsv", header=TRUE)

# %%
# Execution time: 6 secs
# Nrows: 1M
tr <- read.delim("D:/Users/arf/OneDrive/Documentos/Aulas/2021/VD/Project/Dataset/TitleRatings.tsv", header=TRUE)

# %%
# Read them all!
# Execution time: ~4 mins
t0 <- Sys.time()

nb <- read.delim("D:/Users/arf/OneDrive/Documentos/Aulas/2021/VD/Project/Dataset/NameBasics.tsv", header=TRUE)
ta <- read.delim("D:/Users/arf/OneDrive/Documentos/Aulas/2021/VD/Project/Dataset/TitleAkas.tsv", header=TRUE)
tb <- read.delim("D:/Users/arf/OneDrive/Documentos/Aulas/2021/VD/Project/Dataset/TitleBasics.tsv", header=TRUE)
tc <- read.delim("D:/Users/arf/OneDrive/Documentos/Aulas/2021/VD/Project/Dataset/TitleCrew.tsv", header=TRUE)
tr <- read.delim("D:/Users/arf/OneDrive/Documentos/Aulas/2021/VD/Project/Dataset/TitleRatings.tsv", header=TRUE)
tp <- read.delim("D:/Users/arf/OneDrive/Documentos/Aulas/2021/VD/Project/Dataset/TitlePrincipals.tsv", header=TRUE)

difftime(Sys.time(), t0)

# %%
# Prepare for plotting
library(ggplot2)
options(repr.plot.width=10, repr.plot.height=7, repr.plot.res = 200)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 4.0.3"

# %%
# Basic scatter
ggplot(tr, aes(x=numVotes, y=averageRating)) + geom_point()
# Out:
# plot without title

# %%
# How many genres are there?
str(unique(tb$genres))
# Out:
# Error in unique(tb$genres): object 'tb' not found
# Traceback:
#
# 1. str(unique(tb$genres))
# 2. unique(tb$genres)

# %%
# Lets merge TitleBasics with TitleRatings
tbtr <- merge(tb,tr, by="tconst")

# %%
head(tbtr,30)
# Out:
#    tconst    titleType primaryTitle
# 1  tt0000001 short     Carmencita
# 2  tt0000002 short     Le clown et ses chiens
# 3  tt0000003 short     Pauvre Pierrot
# 4  tt0000004 short     Un bon bock
# 5  tt0000005 short     Blacksmith Scene
# 6  tt0000006 short     Chinese Opium Den
# 7  tt0000007 short     Corbett and Courtney Before the Kinetograph
# 8  tt0000008 short     Edison Kinetoscopic Record of a Sneeze
# 9  tt0000009 movie     Miss Jerry
# 10 tt0000010 short     Leaving the Factory
# 11 tt0000011 short     Akrobatisches Potpourri
# 12 tt0000012 short     The Arrival of a Train
# 13 tt0000013 short     The Photographical Congress Arrives in Lyon
# 14 tt0000014 short     The Waterer Watered
# 15 tt0000015 short     Autour d'une cabine
# 16 tt0000016 short     Barque sortant du port
# 17 tt0000017 short     Italienischer Bauerntanz
# 18 tt0000018 short     Das boxende KÃ¤nguruh
# 19 tt0000019 short     The Clown Barber
# 20 tt0000020 short     The Derby 1895
# ...

# %%
unique(tbtr$titleType)
# Out:
#  [1] "short"        "movie"        "tvShort"      "tvSeries"     "tvMovie"
#  [6] "tvEpisode"    "tvMiniSeries" "tvSpecial"    "video"        "videoGame"

# %%
# what's the panorama on the title type?
ggplot(tbtr, aes(x=titleType)) + geom_histogram(stat="count")
# Out:
# Warning message:
# "Ignoring unknown parameters: binwidth, bins, pad"
# plot without title

# %%
# Envision trouble with runtime-duration.
ggplot(head(tbtr,300), aes(x=runtimeMinutes)) + geom_histogram(stat="count")
# Out:
# Warning message:
# "Ignoring unknown parameters: binwidth, bins, pad"
# plot without title

# %%
# For using write_tsv
library(readr)
# Out:
# Warning message:
# "package 'readr' was built under R version 4.0.3"

# %%
# Save the new merged table
t0 <- Sys.time()
write_tsv(tbtr, file="./Dataset/tbtr.tsv")
difftime(Sys.time(), t0)
# Out:
# Time difference of 6.500346 secs
